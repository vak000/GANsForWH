# %%
# !python Scripts/assembly.py Scripts/project.conf

# %%
# !python Scripts/geocoding_assembleddata.py Scripts/project-aoi.conf

# %%
# !python Scripts/ass_coh_estimation.py Scripts/project.conf

# %%
# !python  Scripts/stacking.py  Scripts/project-aoi.conf
# Out:
# R:\Projects\347041 DIABOLO\Ireland
# R:\UtenBackup\Sentinel_1\Ireland
# R:\Projects\347041 DIABOLO\Ireland\SNAP2STAMPS
# IW2
# c:\Program Files\snap\bin\gpt
# ['S1_20160209_IW2.tif', 'S1_20160304_IW2.tif', 'S1_20160316_IW2.tif', 'S1_20160328_IW2.tif', 'S1_20160409_IW2.tif', 'S1_20160421_IW2.tif', 'S1_20160503_IW2.tif', 'S1_20160515_IW2.tif', 'S1_20160527_IW2.tif', 'S1_20160608_IW2.tif', 'S1_20160702_IW2.tif', 'S1_20160714_IW2.tif', 'S1_20160726_IW2.tif', 'S1_20160807_IW2.tif', 'S1_20160819_IW2.tif', 'S1_20160831_IW2.tif', 'S1_20160912_IW2.tif', 'S1_20160924_IW2.tif', 'S1_20160930_IW2.tif', 'S1_20161006_IW2.tif', 'S1_20161018_IW2.tif', 'S1_20161024_IW2.tif', 'S1_20161030_IW2.tif', 'S1_20161105_IW2.tif', 'S1_20161111_IW2.tif', 'S1_20161123_IW2.tif', 'S1_20161205_IW2.tif', 'S1_20161217_IW2.tif', 'S1_20161229_IW2.tif']
#
# #####################################################################
#
# ## Layer Stacking in SNAP
#
#
# ...

# %%
# !python  Scripts/stacking.py  Scripts/project-aoi.conf
# Out:
# R:\Projects\347041 DIABOLO\Ireland
# R:\UtenBackup\Sentinel_1\Ireland
# R:\Projects\347041 DIABOLO\Ireland\SNAP2STAMPS
# IW2
# c:\Program Files\snap\bin\gpt
# ['S1A_20170110_IW2.tif', 'S1A_20170203_IW2.tif', 'S1A_20170215_IW2.tif', 'S1A_20170227_IW2.tif', 'S1A_20170311_IW2.tif', 'S1A_20170323_IW2.tif', 'S1A_20170404_IW2.tif', 'S1A_20170416_IW2.tif', 'S1A_20170428_IW2.tif', 'S1A_20170510_IW2.tif', 'S1A_20170522_IW2.tif', 'S1A_20170603_IW2.tif', 'S1A_20170615_IW2.tif', 'S1A_20170627_IW2.tif', 'S1A_20170709_IW2.tif', 'S1A_20170721_IW2.tif', 'S1A_20170802_IW2.tif', 'S1A_20170814_IW2.tif', 'S1A_20170826_IW2.tif', 'S1A_20170907_IW2.tif', 'S1A_20170919_IW2.tif', 'S1A_20171013_IW2.tif', 'S1A_20171025_IW2.tif', 'S1A_20171106_IW2.tif', 'S1A_20171118_IW2.tif', 'S1A_20171130_IW2.tif', 'S1A_20171212_IW2.tif', 'S1A_20171224_IW2.tif']
#
# #####################################################################
#
# ## Layer Stacking in SNAP
#
#
# ...

# %%
import os
outputCOHfolder=r'R:\Projects\347041 DIABOLO\Ireland\RTC_ASC'

os.chdir(outputCOHfolder)
os.getcwd()

import os
for file in os.listdir("."):
    #os.rename(file, file.replace("IW2", "IW1"))
    os.rename(file, file.replace("S1B", "S1"))
